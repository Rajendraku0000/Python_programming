# %%
from tkinter import *
from PIL import ImageTk, Image  # for iamgeing processing ke liye 
from tkinter import messagebox

root = Tk()
root.title("Login Form")
root.iconbitmap("C:\\Users\\rajen\\OneDrive\\Desktop\\r.jpg")
# root.minsize(100,100)
# root.maxsize(500,500)   
root.geometry("500x500")  # for fixed size 

# color 
root.configure(background="red")

# # for image show

# img = Image.open("C:\\Users\\rajen\\OneDrive\\Desktop\\r.jpg")
# resized_img = img.resize((70,70))
# img = ImageTk.PhotoImage(resized_img)

# img_label = Label(root,image=img)
# img_label.pack(pady=(10,10))

# # for pace the image 
# img_label.pack()


def handle_login():
    email=email_input.get()
    password=pass_input.get()
    
    
    if email == 'rajendraku0000@gmail.com' and password == '1234':
        messagebox.showinfo('Yayyy','Login Successful')
    else:
        messagebox.showerror('Error','Login Failed')


email_label=Label(root,text="Enter Email",fg="white",background="blue")
email_label.pack(ipady=5,pady=(20,5))
email_label.config(font="Verdana")

email_input=Entry(root)
email_input.pack(ipady=5,pady=(20,20))

pass_label=Label(root,text="Enter Password",fg="white",background="blue")
pass_label.pack(ipady=5,pady=(20,5))
pass_label.config(font="Verdana")

pass_input=Entry(root)
pass_input.pack(ipady=5,pady=(20,20))

login_but=Button(root,text="Login Here",bg="white",background="white",command=handle_login)
login_but.pack(ipady=5,pady=(50,5))


root.mainloop()
